# %% [markdown]
# # Road Safety Data in the UK
#
# #### The Data
# The files provide detailed road safety data about the circumstances of personal injury road accidents in GB, the types (including Make and Model) of vehicles involved and the consequential casualties. The statistics relate only to personal injury accidents on public roads that are reported to the police, and subsequently recorded, using the STATS19 accident reporting form. The files used here span 2013 to 2017.
#
# #### The Task
# The purpose of the analysis is
# - To summarize the main characteristics of the data, and obtain interesting facts that are worth highlighting.
# - Identity and quantify associations (if any) between the number of causalities (in the Accidents table) and other variables in the data set.
# - Explore whether it is possible to predict accident hotspots based on the data.
#
# #### The OSEMiN-approach
#
# The OSEMiN Process is an acronym that rhymes with “awesome” and stands for **Obtain, Scrub, Explore, Model, and iNterpret**. It can be used as a blueprint for working on data problems using machine learning tools. Preprocessing involves scrubbing (also called cleaning) and exploring the data. Building the model, evaluating, and optimizing it make up the process of machine learning.

# %% [markdown]
# # Table of Contents
# <a id='Table of Contents'></a>
#
# ### <a href='#1. Obtaining and Viewing the Data'>1. Obtaining and Viewing the Data</a>
#
# ### <a href='#2. Preprocessing the Data'>2. Preprocessing the Data</a>
#
# ### <a href='#3. Data Visualization'>3. Data Visualization</a>
#
# ### <a href='#4. Modeling the Data'>4. Modeling the Data</a>
#
# * <a href='#4.1. Recoding Categorical Features'>4.1. Recoding Categorical Features</a>
# * <a href='#4.2. Training a Logistic Regression'>4.2. Training a Logistic Regression</a>
#
# ### <a href='#5. Interpreting the Data'>5. Interpreting the Data</a>

# %% [markdown]
# ### 1. Obtaining and Viewing the Data
# <a id='1. Obtaining and Viewing the Data'></a>

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# **Accidents Table**

# %%
df1 = pd.read_csv('data/dftRoadSafetyData_Accidents_2017.zip', compression='zip')
print(df1.shape)
df1.head()
# Out:
# (129982, 32)
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  2017010001708               532920.0                196330.0  -0.080107
# 1  2017010009342               526790.0                181970.0  -0.173845
# 2  2017010009344               535200.0                181260.0  -0.052969
# 3  2017010009348               534340.0                193560.0  -0.060658
# 4  2017010009350               533680.0                187820.0  -0.072372
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.650061             1                  1                   2
# 1  51.522425             1                  3                   2
# 2  51.514096             1                  3                   3
# 3  51.624832             1                  3                   2
# 4  51.573408             1                  2                   1
#
#    Number_of_Casualties        Date  ...  Pedestrian_Crossing-Human_Control  \
# 0                     3  05/08/2017  ...                                  0
# 1                     1  01/01/2017  ...                                  0
# 2                     1  01/01/2017  ...                                  0
# 3                     1  01/01/2017  ...                                  0
# 4                     1  01/01/2017  ...                                  0
#
#   Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 0                                       0                 4
# 1                                       0                 4
# 2                                       0                 4
# 3                                       4                 4
# 4                                       5                 4
#
#   Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site  \
# 0                  1                        1                           0
# 1                  1                        2                           0
# 2                  1                        1                           0
# 3                  2                        2                           0
# 4                  1                        2                           0
#
#    Carriageway_Hazards  Urban_or_Rural_Area  \
# 0                    0                    1
# 1                    0                    1
# 2                    0                    1
# 3                    0                    1
# 4                    0                    1
#
#    Did_Police_Officer_Attend_Scene_of_Accident  LSOA_of_Accident_Location
# 0                                            1                  E01001450
# 1                                            1                  E01004702
# 2                                            1                  E01004298
# 3                                            1                  E01001429
# 4                                            1                  E01001808
#
# [5 rows x 32 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129982 entries, 0 to 129981
# Data columns (total 32 columns):
# Accident_Index                                 129982 non-null object
# Location_Easting_OSGR                          129963 non-null float64
# Location_Northing_OSGR                         129963 non-null float64
# Longitude                                      129953 non-null float64
# Latitude                                       129953 non-null float64
# Police_Force                                   129982 non-null int64
# Accident_Severity                              129982 non-null int64
# Number_of_Vehicles                             129982 non-null int64
# Number_of_Casualties                           129982 non-null int64
# Date                                           129982 non-null object
# Day_of_Week                                    129982 non-null int64
# Time                                           129979 non-null object
# Local_Authority_(District)                     129982 non-null int64
# Local_Authority_(Highway)                      129982 non-null object
# 1st_Road_Class                                 129982 non-null int64
# 1st_Road_Number                                129982 non-null int64
# Road_Type                                      129982 non-null int64
# Speed_limit                                    129982 non-null int64
# Junction_Detail                                129982 non-null int64
# Junction_Control                               129982 non-null int64
# 2nd_Road_Class                                 129982 non-null int64
# 2nd_Road_Number                                129982 non-null int64
# Pedestrian_Crossing-Human_Control              129982 non-null int64
# Pedestrian_Crossing-Physical_Facilities        129982 non-null int64
# Light_Conditions                               129982 non-null int64
# Weather_Conditions                             129982 non-null int64
# Road_Surface_Conditions                        129982 non-null int64
# Special_Conditions_at_Site                     129982 non-null int64
# Carriageway_Hazards                            129982 non-null int64
# Urban_or_Rural_Area                            129982 non-null int64
# Did_Police_Officer_Attend_Scene_of_Accident    129982 non-null int64
# LSOA_of_Accident_Location                      122851 non-null object
# dtypes: float64(4), int64(23), object(5)
# memory usage: 31.7+ MB

# %% [markdown]
# The accidents table contains almost 130.000 records and 32 columns, with only very few missing values. If we decided to work with date and/or time, we are likely to convert the string values into datetime format. Besides that, almost all data is properly stored as numeric data.

# %%
#df_acc = pd.concat(map(pd.read_csv, ['data/d1.csv', 'data/d2.csv', 'data/d3.csv']), compression='zip')

import glob
df_test = pd.concat([pd.read_csv(f, compression='zip') for f in glob.glob('data/*Accidents*.zip')])
df_test.shape
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# (691641, 32)

# %%
df_test.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201501BS70001               525130.0                180050.0  -0.198465
# 1  201501BS70002               526530.0                178560.0  -0.178838
# 2  201501BS70004               524610.0                181080.0  -0.205590
# 3  201501BS70005               524420.0                181080.0  -0.208327
# 4  201501BS70008               524630.0                179040.0  -0.206022
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.505538             1                  3                   1
# 1  51.491836             1                  3                   1
# 2  51.514910             1                  3                   1
# 3  51.514952             1                  3                   1
# 4  51.496572             1                  2                   2
#
#    Number_of_Casualties        Date  ...  Pedestrian_Crossing-Human_Control  \
# 0                     1  12/01/2015  ...                                  0
# 1                     1  12/01/2015  ...                                  0
# 2                     1  12/01/2015  ...                                  0
# 3                     1  13/01/2015  ...                                  0
# 4                     1  09/01/2015  ...                                  0
#
#   Pedestrian_Crossing-Physical_Facilities  Light_Conditions  \
# 0                                       0                 4
# 1                                       0                 1
# 2                                       1                 4
# 3                                       0                 1
# 4                                       5                 1
#
#   Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site  \
# 0                  1                        1                           0
# 1                  1                        1                           0
# 2                  2                        2                           0
# 3                  1                        2                           0
# 4                  2                        2                           0
#
#    Carriageway_Hazards  Urban_or_Rural_Area  \
# 0                    0                    1
# 1                    0                    1
# 2                    0                    1
# 3                    0                    1
# 4                    0                    1
#
#    Did_Police_Officer_Attend_Scene_of_Accident  LSOA_of_Accident_Location
# 0                                            1                  E01002825
# 1                                            1                  E01002820
# 2                                            1                  E01002833
# 3                                            2                  E01002874
# 4                                            2                  E01002814
#
# [5 rows x 32 columns]

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138660 entries, 0 to 138659
# Data columns (total 32 columns):
# Accident_Index                                 138660 non-null object
# Location_Easting_OSGR                          138660 non-null int64
# Location_Northing_OSGR                         138660 non-null int64
# Longitude                                      138660 non-null float64
# Latitude                                       138660 non-null float64
# Police_Force                                   138660 non-null int64
# Accident_Severity                              138660 non-null int64
# Number_of_Vehicles                             138660 non-null int64
# Number_of_Casualties                           138660 non-null int64
# Date                                           138660 non-null object
# Day_of_Week                                    138660 non-null int64
# Time                                           138652 non-null object
# Local_Authority_(District)                     138660 non-null int64
# Local_Authority_(Highway)                      138660 non-null object
# 1st_Road_Class                                 138660 non-null int64
# 1st_Road_Number                                138660 non-null int64
# Road_Type                                      138660 non-null int64
# Speed_limit                                    138660 non-null int64
# Junction_Detail                                138660 non-null int64
# Junction_Control                               138660 non-null int64
# 2nd_Road_Class                                 138660 non-null int64
# 2nd_Road_Number                                138660 non-null int64
# Pedestrian_Crossing-Human_Control              138660 non-null int64
# Pedestrian_Crossing-Physical_Facilities        138660 non-null int64
# Light_Conditions                               138660 non-null int64
# Weather_Conditions                             138660 non-null int64
# Road_Surface_Conditions                        138660 non-null int64
# Special_Conditions_at_Site                     138660 non-null int64
# Carriageway_Hazards                            138660 non-null int64
# Urban_or_Rural_Area                            138660 non-null int64
# Did_Police_Officer_Attend_Scene_of_Accident    138660 non-null int64
# LSOA_of_Accident_Location                      128896 non-null object
# dtypes: float64(2), int64(25), object(5)
# memory usage: 33.9+ MB

# %% [markdown]
# **Casualties Table**

# %%
df2 = pd.read_csv('data/dftRoadSafetyData_Casualties_2017.zip', compression='zip')
print(df2.shape)
df2.head()
# Out:
# (170993, 16)
#   Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  2017010001708                  1                   1               2
# 1  2017010001708                  2                   2               1
# 2  2017010001708                  2                   3               2
# 3  2017010009342                  1                   1               2
# 4  2017010009344                  3                   1               1
#
#    Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                2               18                     4                  3
# 1                1               19                     4                  2
# 2                1               18                     4                  1
# 3                2               33                     6                  3
# 4                2               31                     6                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# 0                    0                    0              1
# 1                    0                    0              0
# 2                    0                    0              0
# 3                    0                    0              1
# 4                    0                    0              0
#
#    Bus_or_Coach_Passenger  Pedestrian_Road_Maintenance_Worker  Casualty_Type  \
# 0                       0                                   0              9
# 1                       0                                   0              2
# 2                       0                                   0              2
# 3                       0                                   0              9
# 4                       0                                   0              9
#
#    Casualty_Home_Area_Type  Casualty_IMD_Decile
# 0                        1                    2
# 1                       -1                   -1
# 2                       -1                   -1
# 3                        1                    5
# 4                        1                    5

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170993 entries, 0 to 170992
# Data columns (total 16 columns):
# Accident_Index                        170993 non-null object
# Vehicle_Reference                     170993 non-null int64
# Casualty_Reference                    170993 non-null int64
# Casualty_Class                        170993 non-null int64
# Sex_of_Casualty                       170993 non-null int64
# Age_of_Casualty                       170993 non-null int64
# Age_Band_of_Casualty                  170993 non-null int64
# Casualty_Severity                     170993 non-null int64
# Pedestrian_Location                   170993 non-null int64
# Pedestrian_Movement                   170993 non-null int64
# Car_Passenger                         170993 non-null int64
# Bus_or_Coach_Passenger                170993 non-null int64
# Pedestrian_Road_Maintenance_Worker    170993 non-null int64
# Casualty_Type                         170993 non-null int64
# Casualty_Home_Area_Type               170993 non-null int64
# Casualty_IMD_Decile                   170993 non-null int64
# dtypes: int64(15), object(1)
# memory usage: 20.9+ MB

# %% [markdown]
# The casualties table has almost 171,000 with 16 columns providing detailed information about the casualties. The data is complete with no missing values and - apart from the index - is stored in a numeric format.

# %% [markdown]
# **Vehicles Table**

# %%
df3 = pd.read_csv('data/dftRoadSafetyData_Vehicles_2017.zip', compression='zip')
print(df3.shape)
df3.head()
# Out:
# (238926, 23)
#   Accident_Index  Vehicle_Reference  Vehicle_Type  Towing_and_Articulation  \
# 0  2017010001708                  1             9                        0
# 1  2017010001708                  2             2                        0
# 2  2017010009342                  1             9                        0
# 3  2017010009342                  2             9                        0
# 4  2017010009344                  1             9                        0
#
#    Vehicle_Manoeuvre  Vehicle_Location-Restricted_Lane  Junction_Location  \
# 0                 18                                 0                  0
# 1                 18                                 0                  0
# 2                 18                                 0                  1
# 3                 18                                 0                  1
# 4                 18                                 0                  1
#
#    Skidding_and_Overturning  Hit_Object_in_Carriageway  \
# 0                         0                          0
# 1                         1                          0
# 2                         0                          0
# 3                         1                          0
# 4                         0                          0
#
#    Vehicle_Leaving_Carriageway  ...  Journey_Purpose_of_Driver  Sex_of_Driver  \
# 0                            0  ...                          6              1
# 1                            0  ...                          6              1
# 2                            0  ...                          6              1
# 3                            0  ...                          6              1
# 4                            0  ...                          6              3
#
#    Age_of_Driver  Age_Band_of_Driver  Engine_Capacity_(CC)  Propulsion_Code  \
# 0             24                   5                  1997                2
# 1             19                   4                    -1               -1
# 2             33                   6                  1797                8
# 3             40                   7                  2204                2
# 4             -1                  -1                    -1               -1
#
#    Age_of_Vehicle  Driver_IMD_Decile  Driver_Home_Area_Type  \
# 0               1                 -1                     -1
# 1              -1                 -1                     -1
# 2               8                  9                      1
# 3              12                  2                      1
# 4              -1                 -1                     -1
#
#    Vehicle_IMD_Decile
# 0                  -1
# 1                  -1
# 2                   9
# 3                   2
# 4                  -1
#
# [5 rows x 23 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238926 entries, 0 to 238925
# Data columns (total 23 columns):
# Accident_Index                      238926 non-null object
# Vehicle_Reference                   238926 non-null int64
# Vehicle_Type                        238926 non-null int64
# Towing_and_Articulation             238926 non-null int64
# Vehicle_Manoeuvre                   238926 non-null int64
# Vehicle_Location-Restricted_Lane    238926 non-null int64
# Junction_Location                   238926 non-null int64
# Skidding_and_Overturning            238926 non-null int64
# Hit_Object_in_Carriageway           238926 non-null int64
# Vehicle_Leaving_Carriageway         238926 non-null int64
# Hit_Object_off_Carriageway          238926 non-null int64
# 1st_Point_of_Impact                 238926 non-null int64
# Was_Vehicle_Left_Hand_Drive?        238926 non-null int64
# Journey_Purpose_of_Driver           238926 non-null int64
# Sex_of_Driver                       238926 non-null int64
# Age_of_Driver                       238926 non-null int64
# Age_Band_of_Driver                  238926 non-null int64
# Engine_Capacity_(CC)                238926 non-null int64
# Propulsion_Code                     238926 non-null int64
# Age_of_Vehicle                      238926 non-null int64
# Driver_IMD_Decile                   238926 non-null int64
# Driver_Home_Area_Type               238926 non-null int64
# Vehicle_IMD_Decile                  238926 non-null int64
# dtypes: int64(22), object(1)
# memory usage: 41.9+ MB

# %% [markdown]
# The vehicles table is the largest of all three and contains roughly 239.000 records with 23 columns with detailed information about the vehicle and its driver. We face no missing values.

# %%
df3.Accident_Index.iloc[1]
# Out:
# 2017010001708

# %% [markdown]
# *Back to: <a href='#Table of contents'> Table of contents</a>*
# ### 2. Preprocessing the Data
# <a id='2. Preprocessing the Data'></a>

# %% [markdown]
# #### 2.1. Renaming Columns
# <a id='2.1. Renaming Columns'></a>

# %%
df1.describe().T
# Out:
#                                                 count           mean  \
# Location_Easting_OSGR                        129963.0  451170.256719
# Location_Northing_OSGR                       129963.0  283578.410194
# Longitude                                    129953.0      -1.268385
# Latitude                                     129953.0      52.439387
# Police_Force                                 129982.0      28.527996
# Accident_Severity                            129982.0       2.800849
# Number_of_Vehicles                           129982.0       1.838147
# Number_of_Casualties                         129982.0       1.315513
# Day_of_Week                                  129982.0       4.105245
# Local_Authority_(District)                   129982.0     328.899286
# 1st_Road_Class                               129982.0       4.224154
# 1st_Road_Number                              129982.0     852.034089
# Road_Type                                    129982.0       5.172832
# Speed_limit                                  129982.0      37.258467
# Junction_Detail                              129982.0       2.259336
# Junction_Control                             129982.0       1.598552
# 2nd_Road_Class                               129982.0       2.632541
# 2nd_Road_Number                              129982.0     301.154729
# Pedestrian_Crossing-Human_Control            129982.0       0.002739
# Pedestrian_Crossing-Physical_Facilities      129982.0       0.823452
# Light_Conditions                             129982.0       2.036597
# Weather_Conditions                           129982.0       1.641535
# Road_Surface_Conditions                      129982.0       1.284093
# Special_Conditions_at_Site                   129982.0       0.072318
# Carriageway_Hazards                          129982.0       0.046714
# Urban_or_Rural_Area                          129982.0       1.327291
# Did_Police_Officer_Attend_Scene_of_Accident  129982.0       1.264744
#
#                                                        std           min  \
# Location_Easting_OSGR                         95152.629739  73639.000000
# Location_Northing_OSGR                       153491.812607  12107.000000
# Longitude                                         1.395881     -7.409550
# Latitude                                          1.382508     49.929558
# Police_Force                                     25.064407      1.000000
# Accident_Severity                                 0.430441      1.000000
# Number_of_Vehicles                                0.722479      1.000000
# Number_of_Casualties                              0.765469      1.000000
# Day_of_Week                                       1.930446      1.000000
# Local_Authority_(District)                      258.587181      1.000000
# 1st_Road_Class                                    1.473923      1.000000
# 1st_Road_Number                                1692.951438      0.000000
# Road_Type                                         1.716943      1.000000
# Speed_limit                                      13.976647     20.000000
# Junction_Detail                                   2.582729     -1.000000
# Junction_Control                                  2.353005     -1.000000
# 2nd_Road_Class                                    3.224473     -1.000000
# 2nd_Road_Number                                1152.369545     -1.000000
# Pedestrian_Crossing-Human_Control                 0.248010     -1.000000
# Pedestrian_Crossing-Physical_Facilities           1.950560     -1.000000
# Light_Conditions                                  1.724019     -1.000000
# Weather_Conditions                                1.843830     -1.000000
# Road_Surface_Conditions                           0.645149     -1.000000
# Special_Conditions_at_Site                        0.670572     -1.000000
# Carriageway_Hazards                               0.563003     -1.000000
# Urban_or_Rural_Area                               0.469390      1.000000
# Did_Police_Officer_Attend_Scene_of_Accident       0.441356      1.000000
#
#                                                        25%            50%  \
# Location_Easting_OSGR                        387278.500000  457594.000000
# Location_Northing_OSGR                       176000.000000  224126.000000
# Longitude                                        -2.190772      -1.149752
# Latitude                                         51.470399      51.900636
# Police_Force                                      5.000000      23.000000
# Accident_Severity                                 3.000000       3.000000
# Number_of_Vehicles                                1.000000       2.000000
# Number_of_Casualties                              1.000000       1.000000
# Day_of_Week                                       2.000000       4.000000
# Local_Authority_(District)                       91.000000     303.000000
# 1st_Road_Class                                    3.000000       4.000000
# 1st_Road_Number                                   0.000000      43.000000
# Road_Type                                         6.000000       6.000000
# Speed_limit                                      30.000000      30.000000
# Junction_Detail                                   0.000000       1.000000
# Junction_Control                                 -1.000000       2.000000
# 2nd_Road_Class                                   -1.000000       3.000000
# 2nd_Road_Number                                   0.000000       0.000000
# Pedestrian_Crossing-Human_Control                 0.000000       0.000000
# Pedestrian_Crossing-Physical_Facilities           0.000000       0.000000
# Light_Conditions                                  1.000000       1.000000
# Weather_Conditions                                1.000000       1.000000
# Road_Surface_Conditions                           1.000000       1.000000
# Special_Conditions_at_Site                        0.000000       0.000000
# Carriageway_Hazards                               0.000000       0.000000
# Urban_or_Rural_Area                               1.000000       1.000000
# Did_Police_Officer_Attend_Scene_of_Accident       1.000000       1.000000
#
#                                                        75%           max
# Location_Easting_OSGR                        528910.000000  6.553910e+05
# Location_Northing_OSGR                       388828.500000  1.177531e+06
# Longitude                                        -0.141685  1.759641e+00
# Latitude                                         53.393024  6.048092e+01
# Police_Force                                     45.000000  9.800000e+01
# Accident_Severity                                 3.000000  3.000000e+00
# Number_of_Vehicles                                2.000000  2.300000e+01
# Number_of_Casualties                              1.000000  4.200000e+01
# Day_of_Week                                       6.000000  7.000000e+00
# Local_Authority_(District)                      513.000000  9.410000e+02
# 1st_Road_Class                                    6.000000  6.000000e+00
# 1st_Road_Number                                 587.000000  9.786000e+03
# Road_Type                                         6.000000  9.000000e+00
# Speed_limit                                      40.000000  7.000000e+01
# Junction_Detail                                   3.000000  9.000000e+00
# Junction_Control                                  4.000000  4.000000e+00
# 2nd_Road_Class                                    6.000000  6.000000e+00
# 2nd_Road_Number                                   0.000000  9.704000e+03
# Pedestrian_Crossing-Human_Control                 0.000000  2.000000e+00
# Pedestrian_Crossing-Physical_Facilities           0.000000  8.000000e+00
# Light_Conditions                                  4.000000  7.000000e+00
# Weather_Conditions                                1.000000  9.000000e+00
# Road_Surface_Conditions                           2.000000  5.000000e+00
# Special_Conditions_at_Site                        0.000000  7.000000e+00
# Carriageway_Hazards                               0.000000  7.000000e+00
# Urban_or_Rural_Area                               2.000000  3.000000e+00
# Did_Police_Officer_Attend_Scene_of_Accident       2.000000  3.000000e+00

# %%
df2.describe().T
# Out:
#                                        count       mean        std  min   25%  \
# Vehicle_Reference                   170993.0   1.482166   0.656579  1.0   1.0
# Casualty_Reference                  170993.0   1.397285   1.125848  1.0   1.0
# Casualty_Class                      170993.0   1.499155   0.726935  1.0   1.0
# Sex_of_Casualty                     170993.0   1.406642   0.492172 -1.0   1.0
# Age_of_Casualty                     170993.0  36.503921  19.283721 -1.0  22.0
# Age_Band_of_Casualty                170993.0   6.298246   2.377378 -1.0   5.0
# Casualty_Severity                   170993.0   2.833812   0.399427  1.0   3.0
# Pedestrian_Location                 170993.0   0.755733   2.119174  0.0   0.0
# Pedestrian_Movement                 170993.0   0.598750   1.926425  0.0   0.0
# Car_Passenger                       170993.0   0.250782   0.576786 -1.0   0.0
# Bus_or_Coach_Passenger              170993.0   0.079307   0.534449 -1.0   0.0
# Pedestrian_Road_Maintenance_Worker  170993.0   0.091629   0.419243 -1.0   0.0
# Casualty_Type                       170993.0   7.270099   8.275476 -1.0   2.0
# Casualty_Home_Area_Type             170993.0   0.796869   1.100744 -1.0   1.0
# Casualty_IMD_Decile                 170993.0   3.227957   3.595264 -1.0  -1.0
#
#                                      50%   75%    max
# Vehicle_Reference                    1.0   2.0  101.0
# Casualty_Reference                   1.0   1.0  201.0
# Casualty_Class                       1.0   2.0    3.0
# Sex_of_Casualty                      1.0   2.0    2.0
# Age_of_Casualty                     33.0  50.0  100.0
# Age_Band_of_Casualty                 6.0   8.0   11.0
# Casualty_Severity                    3.0   3.0    3.0
# Pedestrian_Location                  0.0   0.0   10.0
# Pedestrian_Movement                  0.0   0.0    9.0
# Car_Passenger                        0.0   0.0    2.0
# Bus_or_Coach_Passenger               0.0   0.0    4.0
# Pedestrian_Road_Maintenance_Worker   0.0   0.0    2.0
# Casualty_Type                        9.0   9.0   98.0
# Casualty_Home_Area_Type              1.0   1.0    3.0
# Casualty_IMD_Decile                  3.0   6.0   10.0
